# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
video = cv2.VideoCapture('./data/video/square30-01.mp4')
print(video.isOpened())
# Out:
# True

# %%
ret, frame = video.read()
print(ret)
print(frame.shape)
# Out:
# True
# (3840, 2160, 3)

# %%
rows = []
while ret == True:
    frame = frame[:,:,2]
    frame = np.mean(frame,axis=0)
    rows.append(frame)
    ret, frame = video.read()
rows = np.array(rows)
print(rows.shape)
# Out:
# (1779, 2160)

# %%
print(rows[0])
# Out:
# [13.09791667 13.10963542 10.03072917 ...  6.0890625   6.0640625
#   6.04140625]

# %%
coefs = [np.corrcoef(rows[0], row)[0,1] for row in rows]
coefs = np.array(coefs)
print(coefs.shape)
# Out:
# (1779,)

# %%
plt.plot(coefs)
plt.xlabel("Frame")
plt.ylabel("Correlation Coefficient")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print(np.argsort(coefs)[::-1][:20])
# Out:
# [   0 1534    1 1533 1532 1531 1530    2 1535 1529    3    4 1528 1536
#  1527 1526 1537 1525 1538 1524]

# %%
lines = rows.T
start_line = lines[-1]
end_line = lines[0]
plt.plot(start_line, 'b',label='First')
plt.plot(end_line, 'r', label="Last")
plt.xlabel("Frame")
plt.ylabel("Pixel value")
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
video = cv2.VideoCapture('data/video/square29-97.mp4')
ret, frame = video.read()
rows = []
while ret == True:
    frame = frame[:,:,2]
    frame = np.mean(frame,axis=0)
    rows.append(frame)
    ret, frame = video.read()
rows = np.array(rows)
coefs = [np.corrcoef(rows[0], row)[0,1] for row in rows]
coefs = np.array(coefs)
plt.plot(coefs)
plt.xlabel("Frame")
plt.ylabel("Correlation Coefficient")
plt.show
print(np.argsort(coefs)[::-1][:20])
# Out:
# [   0 1471 1472 1470    1 1473    2 1469    3 1468 1474 1475 1467    4
#  1476    5 1466    6 1477 1465]

# %%
# 走査線は右から始まってるっぽい
# 各rowの最後が走査線の最初（紛らわしい）
lines = rows.T
start_line = lines[-1]
end_line = lines[0]
plt.plot(start_line, 'b',label='First')
plt.plot(end_line, 'r', label="Last")
plt.xlabel("Frame")
plt.ylabel("Pixel value")
plt.legend(loc='lower right')
plt.show()

# %%
for i,x in enumerate( start_line[1000:]):
    if(x>16):
        print(i)
        break
# Out:
# 366

# %%
print(start_line[1366])
# Out:
# 16.52890625

# %%
for i,x in enumerate( end_line[1000:]):
    if(x>16):
        print(i)
        break
# Out:
# 660

# %%
print(end_line[1660])
# Out:
# 16.68125

# %%
video = cv2.VideoCapture('video/exp1ms.mp4')
ret, frame = video.read()
rows = []
while ret == True:
    frame = frame[:,:,2]
    frame = np.mean(frame,axis=0)
    rows.append(frame)
    ret, frame = video.read()
rows = np.array(rows)
coefs = [np.corrcoef(rows[0], row)[0,1] for row in rows]
coefs = np.array(coefs)
plt.plot(coefs)
plt.show
print(np.argsort(coefs)[::-1][:20])
# Out:
# [   0    1 1467 1466 1468 1469    2 1470    3 1471 1465 1472 1464    4
#  1463 1462 1473    5    6 1461]

# %%
print(coefs[1465:1475])
# Out:
# [0.99735304 0.9993402  0.9994743  0.99918876 0.99896402 0.99755134
#  0.9974062  0.99633544 0.99238219 0.99119368]

# %%
# 走査線は右から始まってるっぽい
# 各rowの最後が走査線の最初（紛らわしい）
lines = rows.T
start_line = lines[-1]
end_line = lines[0]
plt.plot(start_line,'b')
plt.plot(end_line,'r')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
for i,x in enumerate( start_line[1000:]):
    if(x>12):
        print(i)
        break
# Out:
# 343

# %%
for i,x in enumerate( end_line[1000:]):
    if(x>12):
        print(i)
        break
# Out:
# 638

# %%
video = cv2.VideoCapture('video/exp05ms.mp4')
ret, frame = video.read()
rows = []
while ret == True:
    frame = frame[:,:,2]
    frame = np.mean(frame,axis=0)
    rows.append(frame)
    ret, frame = video.read()
rows = np.array(rows)
coefs = [np.corrcoef(rows[0], row)[0,1] for row in rows]
coefs = np.array(coefs)
plt.plot(coefs)
plt.show
print(np.argsort(coefs)[::-1][:20])
# Out:
# [   0    1    2    3    4    5 1471    6 1470 1469 1473    7 1468 1472
#  1467 1474    8 1466 1465 1464]

# %%
# 走査線は右から始まってるっぽい
# 各rowの最後が走査線の最初（紛らわしい）
lines = rows.T
start_line = lines[-1]
end_line = lines[0]
plt.plot(start_line,'b')
plt.plot(end_line,'r')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
for i,x in enumerate( start_line[1000:]):
    if(x>11):
        print(i)
        break
# Out:
# 386

# %%
for i,x in enumerate( end_line[1000:]):
    if(x>11):
        print(i)
        break
# Out:
# 680

# %%
video = cv2.VideoCapture('video/exp05ms-2.mp4')
ret, frame = video.read()
rows = []
while ret == True:
    frame = frame[:,:,2]
    frame = np.mean(frame,axis=0)
    rows.append(frame)
    ret, frame = video.read()
rows = np.array(rows)
coefs = [np.corrcoef(rows[0], row)[0,1] for row in rows]
coefs = np.array(coefs)
plt.plot(coefs)
plt.show
print(np.argsort(coefs)[::-1][:20])
# Out:
# [   0    1    2    3    4    5 1473 1472 1471 1470 1474 1475 1469 1476
#  1468    6 1477 1467    7 1478]

# %%
# 走査線は右から始まってるっぽい
# 各rowの最後が走査線の最初（紛らわしい）
lines = rows.T
start_line = lines[-1]
end_line = lines[0]
plt.plot(start_line,'b')
plt.plot(end_line,'r')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
for i,x in enumerate( start_line[1000:]):
    if(x>11):
        print(i)
        break
# Out:
# 379

# %%
for i,x in enumerate( end_line[1000:]):
    if(x>11):
        print(i)
        break
# Out:
# 672

# %%
video = cv2.VideoCapture('video/exp05ms-3.mp4')
ret, frame = video.read()
rows = []
while ret == True:
    frame = frame[:,:,2]
    frame = np.mean(frame,axis=0)
    rows.append(frame)
    ret, frame = video.read()
rows = np.array(rows)
coefs = [np.corrcoef(rows[0], row)[0,1] for row in rows]
coefs = np.array(coefs)
plt.plot(coefs)
plt.show
print(np.argsort(coefs)[::-1][:20])
# Out:
# [   0    1    2    3    4    5 1472 1473 1471 1474    6 1475 1470 1469
#     7 1468 1476 1467 1477    8]

# %%
# 走査線は右から始まってるっぽい
# 各rowの最後が走査線の最初（紛らわしい）
lines = rows.T
start_line = lines[-1]
end_line = lines[0]
plt.plot(start_line,'b')
plt.plot(end_line,'r')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
for i,x in enumerate( start_line[1000:]):
    if(x>11):
        print(i)
        break
# Out:
# 419

# %%
for i,x in enumerate( end_line[1000:]):
    if(x>11):
        print(i)
        break
# Out:
# 710
